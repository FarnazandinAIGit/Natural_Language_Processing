# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# ### **Business Context**

# %% [markdown]
# In today's dynamic business landscape, organizations are increasingly recognizing the pivotal role customer feedback plays in shaping the trajectory of their products and services. The ability to **swiftly and effectively respond to customer input** not only fosters enhanced customer experiences but also serves as a catalyst for growth, prolonged customer engagement, and the nurturing of lifetime value relationships.
#
# As a dedicated Product Manager or Product Analyst, staying attuned to the voice of your customers is not just a best practice; it's a strategic imperative.
#
# While your organization may be inundated with a wealth of customer-generated feedback and support tickets, your role entails much more than just processing these inputs. To make your efforts in managing customer experience and expectations truly impactful, you need a structured approach – a method that allows you to discern the most pressing issues, set priorities, and allocate resources judiciously.
#
# One of the most effective strategies at your disposal as an organization is to harness the power of automated Support Ticket Categorization - **done in the modern day using Large Language Models and Generative AI.**

# %% [markdown]
# ### **Objective**

# %% [markdown]
# Develop a Generative AI application using a Large Language Model to **automate the classification and processing of support tickets.** The application will aim to predict ticket categories, assign priority, suggest estimated resolution times, generate responses based on sentiment analysis, and store the results in a structured DataFrame.

# %% [markdown]
# ## **Installing and Importing Necessary Libraries and Dependencies**

# %%
# Installation for CPU llama-cpp-python
# !CMAKE_ARGS="-DLLAMA_CUBLAS=off" FORCE_CMAKE=1 pip install llama-cpp-python==0.1.85 --force-reinstall --no-cache-dir -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 195.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 150.8 MB/s eta 0:00:00
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.0+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.

# %%
# Installation of the hugging face hub
# !pip install huggingface_hub==0.20.3 pandas==1.5.3 -q

# %%
# Importing library for data manipulation
import pandas as pd

# Function to download the model from the Hugging Face model hub
from huggingface_hub import hf_hub_download

# Importing the Llama class from the llama_cpp module
from llama_cpp import Llama

# Importing the json module
import json

# %% [markdown]
# ## **Loading the Dataset**

# %%
# Mounting the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the CSV file
data = pd.read_csv("/content/drive/MyDrive/AL ML program/Introduction to Natural Language Processing/project6/Support_ticket_text_data_mid_term.csv")

# %% [markdown]
# ## **Data Overview**

# %%
# Checking the first 5 rows of the data
data.head()
# Out:
#   support_tick_id                                support_ticket_text
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...

# %%
# Checking the shape of the data
data.shape
# Out:
# (21, 2)

# %%
# Checking for missing values in the data
data.isnull().sum()
# Out:
# support_tick_id        0
# support_ticket_text    0
# dtype: int64

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# ### Loading the model

# %%
# Loading the model TheBloke/Llama-2-13B-chat-GGUF from Hugging Face
model_name_or_path = "TheBloke/Llama-2-13B-chat-GGUF"
model_basename = "llama-2-13b-chat.Q5_K_M.gguf" # the model is in gguf format

# %%
# Using hf_hub_download to download the model from the Hugging Face model hub
# The repo_id parameter specifies the model name or path in the Hugging Face repository
# The filename parameter specifies the name of the file to download
model_path = hf_hub_download(
    repo_id = model_name_or_path,
    filename = model_basename
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# llama-2-13b-chat.Q5_K_M.gguf:   0%|          | 0.00/9.23G [00:00<?, ?B/s]

# %%
# Creating an instance of the 'Llama' class with specified parameters

lcpp_llm = Llama(
    model_path=model_path,
    n_threads=2,  # CPU cores
    n_batch=512,
    n_gpu_layers=43,
    n_ctx=4096,  # Context window
)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# ### Utility functions

# %%
def generate_llama_response(instruction, review):

    # System message explicitly instructing not to include the review text
    system_message = """
        [INST]<<SYS>>
        {}
        <</SYS>>[/INST]
    """.format(instruction)

    # Combining user_prompt and system_message to create the prompt
    prompt = f"{review}\n{system_message}"

    # Generating a response from the LLaMA model
    response = lcpp_llm(
        prompt=prompt,
        max_tokens=1024,
        temperature=0.01,
        top_p=0.95,
        repeat_penalty=1.2,
        top_k=50,
        stop=['INST'],
        echo=False,
    )

    # Extracting the sentiment from the response
    response_text = response["choices"][0]["text"]
    return response_text

# %% [markdown]
# ## **Task 1: Ticket Categorization and Returning Structured Output**

# %%
# Creating a copy of the data
data_1 = data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8d63143ea061> in <cell line: 2>()
#       1 # Creating a copy of the data
# ----> 2 data_1 = data.copy()
#
# NameError: name 'data' is not defined

# %%
# Writing a prompt to get the desired output for ticket categorization
instruction_1 = """
    Read the following support ticket text and categorize the issue. Provide the category for a response or solution. Use the following format:

    Category: [Choose from Hardware Issues, Data Recovery, Technical Issues]
"""

# %%
# Applying the prompt to the model and getting the model response for ticket categorization
data_1['llama_response'] = data_1['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_1, x))
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a55f5dcdfc63> in <cell line: 2>()
#       1 # Applying the prompt to the model and getting the model response for ticket categorization
# ----> 2 data_1['llama_response'] = data_1['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_1, x))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-17-a55f5dcdfc63> in <lambda>(x)
#       1 # Applying the prompt to the model and getting the model response for ticket categorization
# ----> 2 data_1['llama_response'] = data_1['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_1, x))
#
# <ipython-input-14-8b9c855954bf> in generate_llama_response(instruction, review)
#      12
#      13     # Generating a response from the LLaMA model
# ---> 14     response = lcpp_llm(
#      15         prompt=prompt,
#      16         max_tokens=1024,
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py in __call__(self, prompt, suffix, max_tokens, temperature, top_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar)
#    1439             Response object containing the generated text.
#    1440         """
# -> 1441         return self.create_completion(
#    1442             prompt=prompt,
#    1443             suffix=suffix,
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py in create_completion(self, prompt, suffix, max_tokens, temperature, top_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar)
#    1390             chunks: Iterator[CompletionChunk] = completion_or_chunks
#    1391             return chunks
# -> 1392         completion: Completion = next(completion_or_chunks)  # type: ignore
#    1393         return completion
#    1394
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py in _create_completion(self, prompt, suffix, max_tokens, temperature, top_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar)
#     943         finish_reason = "length"
#     944         multibyte_fix = 0
# --> 945         for token in self.generate(
#     946             prompt_tokens,
#     947             top_k=top_k,
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py in generate(self, tokens, top_k, top_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, logits_processor, stopping_criteria, grammar)
#     763
#     764         while True:
# --> 765             self.eval(tokens)
#     766             token = self.sample(
#     767                 top_k=top_k,
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py in eval(self, tokens)
#     482             n_past = min(n_ctx - len(batch), len(self._input_ids))
#     483             n_tokens = len(batch)
# --> 484             return_code = llama_cpp.llama_eval(
#     485                 ctx=self.ctx,
#     486                 tokens=(llama_cpp.llama_token * len(batch))(*batch),
#
# /usr/local/lib/python3.10/dist-packages/llama_cpp/llama_cpp.py in llama_eval(ctx, tokens, n_tokens, n_past, n_threads)
#     806     n_threads: c_int,
#     807 ) -> int:
# --> 808     return _lib.llama_eval(ctx, tokens, n_tokens, n_past, n_threads)
#     809
#     810
#
# KeyboardInterrupt:

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_1.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response
# 0   Sure! Here's the categorization of your suppo...
# 1                         Category: Technical Issues
# 2   Category: Data Recovery\n\nBased on your desc...
# 3   Sure! Here's the categorization of your suppo...
# 4   Category: Technical Issues\n\nBased on your d...

# %%
# Defining a function to extract category from the model response
def extract_category(model_response):
    if 'technical issues' in model_response.lower():
        return 'Technical issues'
    elif 'hardware issues' in model_response.lower():
        return 'Hardware issues'
    elif 'data recovery' in model_response.lower():
        return 'Data recovery'

# %%
# Applying the extract category function to draw the category type from the model response
data_1['Category'] = data_1['llama_response'].apply(extract_category)
data_1['Category'].head()
# Out:
# 0    Technical issues
# 1    Technical issues
# 2       Data recovery
# 3    Technical issues
# 4    Technical issues
# Name: Category, dtype: object

# %%
# Droping the model response from the dataset
final_data_1 = data_1.drop(['llama_response'], axis=1)
final_data_1.head(21)
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#             Category
# 0   Technical issues
# 1   Technical issues
# 2      Data recovery
# 3   Technical issues
# 4   Technical issues
# 5   Technical issues
# 6   Technical issues
# 7    Hardware issues
# 8      Data recovery
# 9    Hardware issues
# 10     Data recovery
# 11   Hardware issues
# 12     Data recovery
# 13     Data recovery
# 14   Hardware issues
# 15  Technical issues
# 16  Technical issues
# 17     Data recovery
# 18     Data recovery
# 19  Technical issues
# 20  Technical issues

# %% [markdown]
# # Observation
#
# The model has successfully generated and extracted the category type for each support ticket, which has been added to the dataset.

# %% [markdown]
# ## **Task 2: Ticket Categorization and Returning Structured Output**

# %%
# creating a copy of the data
data_2 = data.copy()

# %%
## Writing a prompt to get the desired output
instruction_2 = """
    Analyze the support ticket text provided and determine the category of the issue. Output the result in JSON format where the 'Category' field should be one of "Hardware Issues", "Data Recovery", or "Technical Issues".

The output should be in the form of a JSON with
"Category": "<Category>"

    Replace the placeholders (<...>) with the appropriate information extracted from the support ticket text.
"""

# %%
# Applying the prompt to the model and getting the model response for ticket categorization
data_2['llama_response'] = data_2['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_2,x))
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       9.04 ms /    15 runs   (    0.60 ms per token,  1659.11 tokens per second)
# llama_print_timings: prompt eval time =     564.58 ms /   171 tokens (    3.30 ms per token,   302.88 tokens per second)
# llama_print_timings:        eval time =     856.37 ms /    14 runs   (   61.17 ms per token,    16.35 tokens per second)
# llama_print_timings:       total time =    1474.81 ms /   185 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.79 ms /    15 runs   (    0.59 ms per token,  1707.46 tokens per second)
# llama_print_timings: prompt eval time =     596.63 ms /   170 tokens (    3.51 ms per token,   284.93 tokens per second)
# llama_print_timings:        eval time =     834.16 ms /    14 runs   (   59.58 ms per token,    16.78 tokens per second)
# llama_print_timings:       total time =    1482.69 ms /   184 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       7.94 ms /    13 runs   (    0.61 ms per token,  1637.07 tokens per second)
# llama_print_timings: prompt eval time =     590.32 ms /   166 tokens (    3.56 ms per token,   281.20 tokens per second)
# llama_print_timings:        eval time =     727.92 ms /    12 runs   (   60.66 ms per token,    16.49 tokens per second)
# llama_print_timings:       total time =    1366.64 ms /   178 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.98 ms /    15 runs   (    0.60 ms per token,  1671.12 tokens per second)
# llama_print_timings: prompt eval time =     598.21 ms /   174 tokens (    3.44 ms per token,   290.87 tokens per second)
# llama_print_timings:        eval time =     849.75 ms /    14 runs   (   60.70 ms per token,    16.48 tokens per second)
# llama_print_timings:       total time =    1502.43 ms /   188 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      11.94 ms /    15 runs   (    0.80 ms per token,  1256.28 tokens per second)
# llama_print_timings: prompt eval time =     584.69 ms /   149 tokens (    3.92 ms per token,   254.84 tokens per second)
# llama_print_timings:        eval time =     848.56 ms /    14 runs   (   60.61 ms per token,    16.50 tokens per second)
# llama_print_timings:       total time =    1506.60 ms /   163 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      11.08 ms /    15 runs   (    0.74 ms per token,  1353.42 tokens per second)
# llama_print_timings: prompt eval time =     581.72 ms /   149 tokens (    3.90 ms per token,   256.14 tokens per second)
# llama_print_timings:        eval time =     836.06 ms /    14 runs   (   59.72 ms per token,    16.75 tokens per second)
# llama_print_timings:       total time =    1501.36 ms /   163 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.88 ms /    15 runs   (    0.59 ms per token,  1688.43 tokens per second)
# llama_print_timings: prompt eval time =     581.43 ms /   152 tokens (    3.83 ms per token,   261.42 tokens per second)
# llama_print_timings:        eval time =     869.87 ms /    14 runs   (   62.13 ms per token,    16.09 tokens per second)
# llama_print_timings:       total time =    1502.91 ms /   166 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       9.07 ms /    15 runs   (    0.60 ms per token,  1654.53 tokens per second)
# llama_print_timings: prompt eval time =     585.17 ms /   153 tokens (    3.82 ms per token,   261.46 tokens per second)
# llama_print_timings:        eval time =     875.65 ms /    14 runs   (   62.55 ms per token,    15.99 tokens per second)
# llama_print_timings:       total time =    1511.49 ms /   167 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       7.54 ms /    13 runs   (    0.58 ms per token,  1724.37 tokens per second)
# llama_print_timings: prompt eval time =     575.73 ms /   147 tokens (    3.92 ms per token,   255.33 tokens per second)
# llama_print_timings:        eval time =     764.31 ms /    12 runs   (   63.69 ms per token,    15.70 tokens per second)
# llama_print_timings:       total time =    1382.23 ms /   159 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.87 ms /    15 runs   (    0.59 ms per token,  1691.09 tokens per second)
# llama_print_timings: prompt eval time =     584.02 ms /   156 tokens (    3.74 ms per token,   267.11 tokens per second)
# llama_print_timings:        eval time =     883.41 ms /    14 runs   (   63.10 ms per token,    15.85 tokens per second)
# llama_print_timings:       total time =    1517.93 ms /   170 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      36.84 ms /    63 runs   (    0.58 ms per token,  1710.33 tokens per second)
# llama_print_timings: prompt eval time =     586.29 ms /   149 tokens (    3.93 ms per token,   254.14 tokens per second)
# llama_print_timings:        eval time =    3940.11 ms /    62 runs   (   63.55 ms per token,    15.74 tokens per second)
# llama_print_timings:       total time =    4737.01 ms /   211 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      10.14 ms /    15 runs   (    0.68 ms per token,  1479.00 tokens per second)
# llama_print_timings: prompt eval time =     585.84 ms /   153 tokens (    3.83 ms per token,   261.16 tokens per second)
# llama_print_timings:        eval time =     843.42 ms /    14 runs   (   60.24 ms per token,    16.60 tokens per second)
# llama_print_timings:       total time =    1508.57 ms /   167 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.78 ms /    13 runs   (    0.68 ms per token,  1480.30 tokens per second)
# llama_print_timings: prompt eval time =     586.75 ms /   153 tokens (    3.83 ms per token,   260.76 tokens per second)
# llama_print_timings:        eval time =     724.85 ms /    12 runs   (   60.40 ms per token,    16.56 tokens per second)
# llama_print_timings:       total time =    1375.25 ms /   165 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      43.03 ms /    74 runs   (    0.58 ms per token,  1719.77 tokens per second)
# llama_print_timings: prompt eval time =     581.17 ms /   145 tokens (    4.01 ms per token,   249.50 tokens per second)
# llama_print_timings:        eval time =    4473.49 ms /    73 runs   (   61.28 ms per token,    16.32 tokens per second)
# llama_print_timings:       total time =    5307.46 ms /   218 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.95 ms /    15 runs   (    0.60 ms per token,  1675.98 tokens per second)
# llama_print_timings: prompt eval time =     575.56 ms /   150 tokens (    3.84 ms per token,   260.62 tokens per second)
# llama_print_timings:        eval time =     825.04 ms /    14 runs   (   58.93 ms per token,    16.97 tokens per second)
# llama_print_timings:       total time =    1451.53 ms /   164 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       9.09 ms /    15 runs   (    0.61 ms per token,  1650.89 tokens per second)
# llama_print_timings: prompt eval time =     558.71 ms /   141 tokens (    3.96 ms per token,   252.37 tokens per second)
# llama_print_timings:        eval time =     807.43 ms /    14 runs   (   57.67 ms per token,    17.34 tokens per second)
# llama_print_timings:       total time =    1417.16 ms /   155 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.64 ms /    15 runs   (    0.58 ms per token,  1735.11 tokens per second)
# llama_print_timings: prompt eval time =     574.18 ms /   146 tokens (    3.93 ms per token,   254.28 tokens per second)
# llama_print_timings:        eval time =     840.37 ms /    14 runs   (   60.03 ms per token,    16.66 tokens per second)
# llama_print_timings:       total time =    1463.43 ms /   160 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       9.21 ms /    13 runs   (    0.71 ms per token,  1411.66 tokens per second)
# llama_print_timings: prompt eval time =     563.25 ms /   141 tokens (    3.99 ms per token,   250.33 tokens per second)
# llama_print_timings:        eval time =     705.14 ms /    12 runs   (   58.76 ms per token,    17.02 tokens per second)
# llama_print_timings:       total time =    1339.24 ms /   153 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       9.29 ms /    13 runs   (    0.71 ms per token,  1398.75 tokens per second)
# llama_print_timings: prompt eval time =     548.81 ms /   142 tokens (    3.86 ms per token,   258.74 tokens per second)
# llama_print_timings:        eval time =     704.55 ms /    12 runs   (   58.71 ms per token,    17.03 tokens per second)
# llama_print_timings:       total time =    1323.11 ms /   154 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      47.91 ms /    81 runs   (    0.59 ms per token,  1690.49 tokens per second)
# llama_print_timings: prompt eval time =     809.62 ms /   298 tokens (    2.72 ms per token,   368.07 tokens per second)
# llama_print_timings:        eval time =    4805.69 ms /    80 runs   (   60.07 ms per token,    16.65 tokens per second)
# llama_print_timings:       total time =    5892.00 ms /   378 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.50 ms /    15 runs   (    0.57 ms per token,  1764.50 tokens per second)
# llama_print_timings: prompt eval time =     915.40 ms /   411 tokens (    2.23 ms per token,   448.98 tokens per second)
# llama_print_timings:        eval time =     823.11 ms /    14 runs   (   58.79 ms per token,    17.01 tokens per second)
# llama_print_timings:       total time =    1788.67 ms /   425 tokens

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_2.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                           llama_response
# 0   {\n"Category": "Technical Issues"\n}
# 1    {\n"Category": "Hardware Issues"\n}
# 2      {\n"Category": "Data Recovery"\n}
# 3   {\n"Category": "Technical Issues"\n}
# 4   {\n"Category": "Technical Issues"\n}

# %%
# defining a function to parse the JSON output from the model
def extract_json_data(json_str):
    try:
        # Finding the indices of the opening and closing curly braces
        json_start = json_str.find('{')
        json_end = json_str.rfind('}')

        if json_start != -1 and json_end != -1:
            extracted_category = json_str[json_start:json_end + 1]  # Extract the JSON object
            data_dict = json.loads(extracted_category)
            return data_dict
        else:
            print(f"Warning: JSON object not found in response: {json_str}")
            return {}
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return {}

# %%
# Applying the extract_json_data function on the llama_response column to create a new column called llama_response_parsed
data_2['llama_response_parsed'] = data_2['llama_response'].apply(extract_json_data)
data_2['llama_response_parsed'].head()
# Out:
# 0    {'Category': 'Technical Issues'}
# 1     {'Category': 'Hardware Issues'}
# 2       {'Category': 'Data Recovery'}
# 3    {'Category': 'Technical Issues'}
# 4    {'Category': 'Technical Issues'}
# Name: llama_response_parsed, dtype: object

# %%
# Applying the json_normalize on llama_response_parsed variable
llama_response_parsed_df_2 = pd.json_normalize(data_2['llama_response_parsed'])
llama_response_parsed_df_2.head()
# Out:
#            Category
# 0  Technical Issues
# 1   Hardware Issues
# 2     Data Recovery
# 3  Technical Issues
# 4  Technical Issues

# %%
# Concatenating data_2 and llama_response_parsed_df_2
data_with_parsed_model_output_2 = pd.concat([data_2, llama_response_parsed_df_2], axis=1)
data_with_parsed_model_output_2.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                           llama_response             llama_response_parsed  \
# 0   {\n"Category": "Technical Issues"\n}  {'Category': 'Technical Issues'}
# 1    {\n"Category": "Hardware Issues"\n}   {'Category': 'Hardware Issues'}
# 2      {\n"Category": "Data Recovery"\n}     {'Category': 'Data Recovery'}
# 3   {\n"Category": "Technical Issues"\n}  {'Category': 'Technical Issues'}
# 4   {\n"Category": "Technical Issues"\n}  {'Category': 'Technical Issues'}
#
#            Category
# 0  Technical Issues
# 1   Hardware Issues
# 2     Data Recovery
# 3  Technical Issues
# 4  Technical Issues

# %%
# Droping the model response, 'llama_response', 'llama_response_parsed', from the dataset
final_data_2 = data_with_parsed_model_output_2.drop(['llama_response','llama_response_parsed'], axis=1)
final_data_2.head(21)
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#             Category
# 0   Technical Issues
# 1    Hardware Issues
# 2      Data Recovery
# 3   Technical Issues
# 4   Technical Issues
# 5   Technical Issues
# 6   Technical Issues
# 7    Hardware Issues
# 8      Data Recovery
# 9    Hardware Issues
# 10     Data Recovery
# 11   Hardware Issues
# 12     Data Recovery
# 13     Data Recovery
# 14   Hardware Issues
# 15  Technical Issues
# 16  Technical Issues
# 17     Data Recovery
# 18     Data Recovery
# 19  Technical Issues
# 20  Technical Issues

# %% [markdown]
# # Observation
#
# The model has identified and extracted the category for each support ticket from its JSON response, incorporating this information into the dataset.
#
# Technical Issues are the most reported, with 9 out of 21 tickets. Data Recovery has 7 tickets, and Hardware Issues have 5. This indicates users face more general technical difficulties than specific hardware problems or data loss scenarios.

# %% [markdown]
# ## **Task 3: Ticket Categorization, Creating Tags, and Returning Structured Output**

# %%
# creating a copy of the data
data_3 = data.copy()

# %%
# Writing a prompt to get the desired output
instruction_3 = """
    Analyze the support ticket text provided and determine the tag of the issue. Output the result in JSON format where the 'Tags' field should be the list of key terms related to the issue.

The output should be in the form of a JSON with
"Tags": "<Tags>"

    Replace the placeholders (<...>) by a list of key terms related to the issue extracted from the support ticket text.
"""

# %%
# Applying the prompt to the model and getting the model response to create tags
data_3['llama_response'] = data_3['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_3,x))
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      28.93 ms /    44 runs   (    0.66 ms per token,  1521.07 tokens per second)
# llama_print_timings: prompt eval time =     546.29 ms /   165 tokens (    3.31 ms per token,   302.03 tokens per second)
# llama_print_timings:        eval time =    2547.66 ms /    43 runs   (   59.25 ms per token,    16.88 tokens per second)
# llama_print_timings:       total time =    3276.53 ms /   208 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.83 ms /    42 runs   (    0.71 ms per token,  1407.98 tokens per second)
# llama_print_timings: prompt eval time =     560.49 ms /   164 tokens (    3.42 ms per token,   292.60 tokens per second)
# llama_print_timings:        eval time =    2375.89 ms /    41 runs   (   57.95 ms per token,    17.26 tokens per second)
# llama_print_timings:       total time =    3139.90 ms /   205 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.96 ms /    51 runs   (    0.59 ms per token,  1702.55 tokens per second)
# llama_print_timings: prompt eval time =     555.37 ms /   160 tokens (    3.47 ms per token,   288.10 tokens per second)
# llama_print_timings:        eval time =    2904.58 ms /    50 runs   (   58.09 ms per token,    17.21 tokens per second)
# llama_print_timings:       total time =    3629.12 ms /   210 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.34 ms /    52 runs   (    0.56 ms per token,  1772.57 tokens per second)
# llama_print_timings: prompt eval time =     577.81 ms /   168 tokens (    3.44 ms per token,   290.75 tokens per second)
# llama_print_timings:        eval time =    2941.01 ms /    51 runs   (   57.67 ms per token,    17.34 tokens per second)
# llama_print_timings:       total time =    3693.63 ms /   219 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      34.66 ms /    49 runs   (    0.71 ms per token,  1413.81 tokens per second)
# llama_print_timings: prompt eval time =     545.63 ms /   143 tokens (    3.82 ms per token,   262.08 tokens per second)
# llama_print_timings:        eval time =    2754.52 ms /    48 runs   (   57.39 ms per token,    17.43 tokens per second)
# llama_print_timings:       total time =    3531.31 ms /   191 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.61 ms /    49 runs   (    0.60 ms per token,  1654.79 tokens per second)
# llama_print_timings: prompt eval time =     543.34 ms /   143 tokens (    3.80 ms per token,   263.19 tokens per second)
# llama_print_timings:        eval time =    2761.19 ms /    48 runs   (   57.52 ms per token,    17.38 tokens per second)
# llama_print_timings:       total time =    3485.87 ms /   191 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      16.45 ms /    27 runs   (    0.61 ms per token,  1641.24 tokens per second)
# llama_print_timings: prompt eval time =     539.26 ms /   146 tokens (    3.69 ms per token,   270.74 tokens per second)
# llama_print_timings:        eval time =    1515.18 ms /    26 runs   (   58.28 ms per token,    17.16 tokens per second)
# llama_print_timings:       total time =    2151.88 ms /   172 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      31.68 ms /    54 runs   (    0.59 ms per token,  1704.60 tokens per second)
# llama_print_timings: prompt eval time =     546.22 ms /   147 tokens (    3.72 ms per token,   269.12 tokens per second)
# llama_print_timings:        eval time =    3072.56 ms /    53 runs   (   57.97 ms per token,    17.25 tokens per second)
# llama_print_timings:       total time =    3799.48 ms /   200 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.16 ms /    43 runs   (    0.68 ms per token,  1474.83 tokens per second)
# llama_print_timings: prompt eval time =     546.35 ms /   141 tokens (    3.87 ms per token,   258.07 tokens per second)
# llama_print_timings:        eval time =    2453.67 ms /    42 runs   (   58.42 ms per token,    17.12 tokens per second)
# llama_print_timings:       total time =    3205.65 ms /   183 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      30.73 ms /    50 runs   (    0.61 ms per token,  1627.13 tokens per second)
# llama_print_timings: prompt eval time =     553.58 ms /   150 tokens (    3.69 ms per token,   270.96 tokens per second)
# llama_print_timings:        eval time =    2940.74 ms /    49 runs   (   60.02 ms per token,    16.66 tokens per second)
# llama_print_timings:       total time =    3681.30 ms /   199 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      31.27 ms /    52 runs   (    0.60 ms per token,  1663.20 tokens per second)
# llama_print_timings: prompt eval time =     556.99 ms /   143 tokens (    3.90 ms per token,   256.74 tokens per second)
# llama_print_timings:        eval time =    2967.99 ms /    51 runs   (   58.20 ms per token,    17.18 tokens per second)
# llama_print_timings:       total time =    3697.86 ms /   194 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      24.65 ms /    43 runs   (    0.57 ms per token,  1744.71 tokens per second)
# llama_print_timings: prompt eval time =     558.67 ms /   147 tokens (    3.80 ms per token,   263.12 tokens per second)
# llama_print_timings:        eval time =    2483.61 ms /    42 runs   (   59.13 ms per token,    16.91 tokens per second)
# llama_print_timings:       total time =    3186.99 ms /   189 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      29.48 ms /    42 runs   (    0.70 ms per token,  1424.79 tokens per second)
# llama_print_timings: prompt eval time =     562.89 ms /   147 tokens (    3.83 ms per token,   261.15 tokens per second)
# llama_print_timings:        eval time =    2398.09 ms /    41 runs   (   58.49 ms per token,    17.10 tokens per second)
# llama_print_timings:       total time =    3191.48 ms /   188 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      26.95 ms /    46 runs   (    0.59 ms per token,  1706.67 tokens per second)
# llama_print_timings: prompt eval time =     550.17 ms /   139 tokens (    3.96 ms per token,   252.65 tokens per second)
# llama_print_timings:        eval time =    2724.27 ms /    45 runs   (   60.54 ms per token,    16.52 tokens per second)
# llama_print_timings:       total time =    3431.30 ms /   184 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      28.84 ms /    48 runs   (    0.60 ms per token,  1664.12 tokens per second)
# llama_print_timings: prompt eval time =     556.79 ms /   144 tokens (    3.87 ms per token,   258.62 tokens per second)
# llama_print_timings:        eval time =    2812.84 ms /    47 runs   (   59.85 ms per token,    16.71 tokens per second)
# llama_print_timings:       total time =    3532.68 ms /   191 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      28.76 ms /    48 runs   (    0.60 ms per token,  1669.22 tokens per second)
# llama_print_timings: prompt eval time =     552.33 ms /   135 tokens (    4.09 ms per token,   244.42 tokens per second)
# llama_print_timings:        eval time =    2877.31 ms /    47 runs   (   61.22 ms per token,    16.33 tokens per second)
# llama_print_timings:       total time =    3605.82 ms /   182 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     172.68 ms /   278 runs   (    0.62 ms per token,  1609.93 tokens per second)
# llama_print_timings: prompt eval time =     552.51 ms /   140 tokens (    3.95 ms per token,   253.39 tokens per second)
# llama_print_timings:        eval time =   16675.84 ms /   277 runs   (   60.20 ms per token,    16.61 tokens per second)
# llama_print_timings:       total time =   18396.21 ms /   417 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      24.32 ms /    42 runs   (    0.58 ms per token,  1727.19 tokens per second)
# llama_print_timings: prompt eval time =     542.58 ms /   135 tokens (    4.02 ms per token,   248.81 tokens per second)
# llama_print_timings:        eval time =    2432.85 ms /    41 runs   (   59.34 ms per token,    16.85 tokens per second)
# llama_print_timings:       total time =    3121.12 ms /   176 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      23.70 ms /    40 runs   (    0.59 ms per token,  1687.55 tokens per second)
# llama_print_timings: prompt eval time =     540.77 ms /   136 tokens (    3.98 ms per token,   251.49 tokens per second)
# llama_print_timings:        eval time =    2337.56 ms /    39 runs   (   59.94 ms per token,    16.68 tokens per second)
# llama_print_timings:       total time =    3013.94 ms /   175 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      96.04 ms /   155 runs   (    0.62 ms per token,  1613.96 tokens per second)
# llama_print_timings: prompt eval time =     809.45 ms /   292 tokens (    2.77 ms per token,   360.74 tokens per second)
# llama_print_timings:        eval time =    9261.83 ms /   154 runs   (   60.14 ms per token,    16.63 tokens per second)
# llama_print_timings:       total time =   10706.21 ms /   446 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      42.25 ms /    65 runs   (    0.65 ms per token,  1538.43 tokens per second)
# llama_print_timings: prompt eval time =     922.78 ms /   405 tokens (    2.28 ms per token,   438.89 tokens per second)
# llama_print_timings:        eval time =    3816.67 ms /    64 runs   (   59.64 ms per token,    16.77 tokens per second)
# llama_print_timings:       total time =    5053.55 ms /   469 tokens

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_3.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response
# 0   Sure! Here is the analysis of the support tic...
# 1   {\n"Tags": ["urgent", "laptop", "start", "har...
# 2   Sure! Here is the analysis of the support tic...
# 3   Sure! Here is the analysis of the support tic...
# 4   Sure! Here's the analysis of the support tick...

# %%
# Applying the extract_json_data function on the llama_response column to create a new column called llama_response_parsed
data_3['llama_response_parsed'] = data_3['llama_response'].apply(extract_json_data)
data_3['llama_response_parsed'].head()
# Out:
# 0    {'Tags': ['Internet Connection', 'Speed', 'Dis...
# 1    {'Tags': ['urgent', 'laptop', 'start', 'hardwa...
# 2    {'Tags': ['Data Loss', 'Essential Documents', ...
# 3    {'Tags': ['Wi-Fi', 'signal strength', 'weak', ...
# 4    {'Tags': ['battery', 'draining', 'rapidly', 'm...
# Name: llama_response_parsed, dtype: object

# %%
# Applying the json_normalize on llama_response_parsed variable
llama_response_parsed_df_3 = pd.json_normalize(data_3['llama_response_parsed'])
llama_response_parsed_df_3.head()
# Out:
#                                                 Tags
# 0  [Internet Connection, Speed, Disconnections, W...
# 1  [urgent, laptop, start, hardware, issue, prese...
# 2  [Data Loss, Essential Documents, Accidental De...
# 3  [Wi-Fi, signal strength, weak, persistent, hom...
# 4  [battery, draining, rapidly, minimal, use, issue]

# %%
# Concatenating data_3 and llama_response_parsed_df_3
data_with_parsed_model_output_3 = pd.concat([data_3, llama_response_parsed_df_3], axis=1)
data_with_parsed_model_output_3.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response  \
# 0   Sure! Here is the analysis of the support tic...
# 1   {\n"Tags": ["urgent", "laptop", "start", "har...
# 2   Sure! Here is the analysis of the support tic...
# 3   Sure! Here is the analysis of the support tic...
# 4   Sure! Here's the analysis of the support tick...
#
#                                llama_response_parsed  \
# 0  {'Tags': ['Internet Connection', 'Speed', 'Dis...
# 1  {'Tags': ['urgent', 'laptop', 'start', 'hardwa...
# 2  {'Tags': ['Data Loss', 'Essential Documents', ...
# 3  {'Tags': ['Wi-Fi', 'signal strength', 'weak', ...
# 4  {'Tags': ['battery', 'draining', 'rapidly', 'm...
#
#                                                 Tags
# 0  [Internet Connection, Speed, Disconnections, W...
# 1  [urgent, laptop, start, hardware, issue, prese...
# 2  [Data Loss, Essential Documents, Accidental De...
# 3  [Wi-Fi, signal strength, weak, persistent, hom...
# 4  [battery, draining, rapidly, minimal, use, issue]

# %%
# Dropping llama_response and llama_response_parsed variables
final_data_3 = data_with_parsed_model_output_3.drop(['llama_response','llama_response_parsed'], axis=1)
final_data_3.head(21)
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#                                                  Tags
# 0   [Internet Connection, Speed, Disconnections, W...
# 1   [urgent, laptop, start, hardware, issue, prese...
# 2   [Data Loss, Essential Documents, Accidental De...
# 3   [Wi-Fi, signal strength, weak, persistent, hom...
# 4   [battery, draining, rapidly, minimal, use, issue]
# 5   [urgent, transaction, password, reset, online,...
# 6   [Computer Performance, Sluggish, Productivity,...
# 7   [Blue Screen Error, Frequent Crashes, Hardware...
# 8   [Data Recovery, External Hard Drive, Not Recog...
# 9   [hardware issue, graphics card, poor gaming pe...
# 10  [data loss, USB drive, critical files, recover...
# 11  [computer, screen, black, fix, urgent, assista...
# 12       [Water Damage, Laptop, Data Recovery, Spill]
# 13  [USB Flash Drive, Physical Damage, File Recove...
# 14  [hardware, touchpad, laptop, troubleshooting, ...
# 15  [internet connection, dropping, frequently, ur...
# 16     [Wi-Fi, inconsistent, proximity, router, work]
# 17  [Data Recovery, USB Drive, Formatted, Crucial ...
# 18  [Hard Drive, Recognition, Data Recovery, Exter...
# 19  [Internet Connection, Speed, Disconnections, P...
# 20  [software compatibility, erratic behavior, dat...

# %% [markdown]
# # Observation
#
# The model has accurately identified the tags for each support ticket, extracted this data from its JSON response, and integrated it into the dataset as a structured entry.

# %% [markdown]
# ## **Task 4 - Ticket Categorization, Creating Tags, Assigning Priority, and Returning Structured Output**

# %%
# Creatng a copy of the data
data_4 = data.copy()

# %%
## Writing a prompt to get the desired output
instruction_4 = """
    Analyze the support ticket text provided and determine the priority of the issue. Output the result in JSON format where the 'Priority' field should be one of "High", "Medium", or "Low".

The output should be in the form of a JSON with
"Priority": "<Priority>"

    Replace the placeholders (<...>) with the appropriate information extracted from the support ticket text.
"""

# %%
# Applying the prompt to the model and getting the model response to create tags by applying the generate_llama_response function to each ticket in the 'support_ticket_text' column of the DataFrame 'data_4'
data_4['llama_response'] = data_4['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_4,x))
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      47.08 ms /    78 runs   (    0.60 ms per token,  1656.61 tokens per second)
# llama_print_timings: prompt eval time =     549.32 ms /   166 tokens (    3.31 ms per token,   302.19 tokens per second)
# llama_print_timings:        eval time =    4592.22 ms /    77 runs   (   59.64 ms per token,    16.77 tokens per second)
# llama_print_timings:       total time =    5412.39 ms /   243 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       6.76 ms /    12 runs   (    0.56 ms per token,  1776.20 tokens per second)
# llama_print_timings: prompt eval time =     579.16 ms /   165 tokens (    3.51 ms per token,   284.89 tokens per second)
# llama_print_timings:        eval time =     657.26 ms /    11 runs   (   59.75 ms per token,    16.74 tokens per second)
# llama_print_timings:       total time =    1275.61 ms /   176 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       6.81 ms /    12 runs   (    0.57 ms per token,  1761.34 tokens per second)
# llama_print_timings: prompt eval time =     581.27 ms /   161 tokens (    3.61 ms per token,   276.98 tokens per second)
# llama_print_timings:        eval time =     643.30 ms /    11 runs   (   58.48 ms per token,    17.10 tokens per second)
# llama_print_timings:       total time =    1264.62 ms /   172 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      63.70 ms /    99 runs   (    0.64 ms per token,  1554.18 tokens per second)
# llama_print_timings: prompt eval time =     574.89 ms /   169 tokens (    3.40 ms per token,   293.97 tokens per second)
# llama_print_timings:        eval time =    5742.46 ms /    98 runs   (   58.60 ms per token,    17.07 tokens per second)
# llama_print_timings:       total time =    6758.93 ms /   267 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      84.23 ms /   140 runs   (    0.60 ms per token,  1662.14 tokens per second)
# llama_print_timings: prompt eval time =     568.22 ms /   144 tokens (    3.95 ms per token,   253.42 tokens per second)
# llama_print_timings:        eval time =    8086.89 ms /   139 runs   (   58.18 ms per token,    17.19 tokens per second)
# llama_print_timings:       total time =    9221.27 ms /   283 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      58.58 ms /    95 runs   (    0.62 ms per token,  1621.66 tokens per second)
# llama_print_timings: prompt eval time =     553.74 ms /   144 tokens (    3.85 ms per token,   260.05 tokens per second)
# llama_print_timings:        eval time =    5529.14 ms /    94 runs   (   58.82 ms per token,    17.00 tokens per second)
# llama_print_timings:       total time =    6469.54 ms /   238 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       6.89 ms /    12 runs   (    0.57 ms per token,  1742.67 tokens per second)
# llama_print_timings: prompt eval time =     556.62 ms /   147 tokens (    3.79 ms per token,   264.09 tokens per second)
# llama_print_timings:        eval time =     666.57 ms /    11 runs   (   60.60 ms per token,    16.50 tokens per second)
# llama_print_timings:       total time =    1261.70 ms /   158 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       7.02 ms /    12 runs   (    0.58 ms per token,  1709.65 tokens per second)
# llama_print_timings: prompt eval time =     551.06 ms /   148 tokens (    3.72 ms per token,   268.57 tokens per second)
# llama_print_timings:        eval time =     667.64 ms /    11 runs   (   60.69 ms per token,    16.48 tokens per second)
# llama_print_timings:       total time =    1259.97 ms /   159 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      31.48 ms /    51 runs   (    0.62 ms per token,  1619.92 tokens per second)
# llama_print_timings: prompt eval time =     566.36 ms /   142 tokens (    3.99 ms per token,   250.72 tokens per second)
# llama_print_timings:        eval time =    2906.29 ms /    50 runs   (   58.13 ms per token,    17.20 tokens per second)
# llama_print_timings:       total time =    3661.32 ms /   192 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.69 ms /    12 runs   (    0.72 ms per token,  1381.06 tokens per second)
# llama_print_timings: prompt eval time =     556.77 ms /   151 tokens (    3.69 ms per token,   271.21 tokens per second)
# llama_print_timings:        eval time =     648.36 ms /    11 runs   (   58.94 ms per token,    16.97 tokens per second)
# llama_print_timings:       total time =    1271.97 ms /   162 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     112.65 ms /   183 runs   (    0.62 ms per token,  1624.52 tokens per second)
# llama_print_timings: prompt eval time =     539.23 ms /   144 tokens (    3.74 ms per token,   267.05 tokens per second)
# llama_print_timings:        eval time =   10748.35 ms /   182 runs   (   59.06 ms per token,    16.93 tokens per second)
# llama_print_timings:       total time =   12007.18 ms /   326 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       8.20 ms /    12 runs   (    0.68 ms per token,  1464.31 tokens per second)
# llama_print_timings: prompt eval time =     559.81 ms /   148 tokens (    3.78 ms per token,   264.38 tokens per second)
# llama_print_timings:        eval time =     652.03 ms /    11 runs   (   59.28 ms per token,    16.87 tokens per second)
# llama_print_timings:       total time =    1274.82 ms /   159 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       7.44 ms /    12 runs   (    0.62 ms per token,  1612.25 tokens per second)
# llama_print_timings: prompt eval time =     562.54 ms /   148 tokens (    3.80 ms per token,   263.09 tokens per second)
# llama_print_timings:        eval time =     671.96 ms /    11 runs   (   61.09 ms per token,    16.37 tokens per second)
# llama_print_timings:       total time =    1283.17 ms /   159 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     103.58 ms /   172 runs   (    0.60 ms per token,  1660.58 tokens per second)
# llama_print_timings: prompt eval time =     553.85 ms /   140 tokens (    3.96 ms per token,   252.78 tokens per second)
# llama_print_timings:        eval time =   10028.20 ms /   171 runs   (   58.64 ms per token,    17.05 tokens per second)
# llama_print_timings:       total time =   11247.49 ms /   311 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     139.35 ms /   220 runs   (    0.63 ms per token,  1578.70 tokens per second)
# llama_print_timings: prompt eval time =     563.71 ms /   145 tokens (    3.89 ms per token,   257.23 tokens per second)
# llama_print_timings:        eval time =   12887.24 ms /   219 runs   (   58.85 ms per token,    16.99 tokens per second)
# llama_print_timings:       total time =   14385.19 ms /   364 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      40.79 ms /    70 runs   (    0.58 ms per token,  1716.15 tokens per second)
# llama_print_timings: prompt eval time =     557.02 ms /   136 tokens (    4.10 ms per token,   244.16 tokens per second)
# llama_print_timings:        eval time =    3991.44 ms /    69 runs   (   57.85 ms per token,    17.29 tokens per second)
# llama_print_timings:       total time =    4782.96 ms /   205 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      95.53 ms /   148 runs   (    0.65 ms per token,  1549.27 tokens per second)
# llama_print_timings: prompt eval time =     554.63 ms /   141 tokens (    3.93 ms per token,   254.22 tokens per second)
# llama_print_timings:        eval time =    8696.61 ms /   147 runs   (   59.16 ms per token,    16.90 tokens per second)
# llama_print_timings:       total time =    9869.72 ms /   288 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =       6.99 ms /    12 runs   (    0.58 ms per token,  1717.23 tokens per second)
# llama_print_timings: prompt eval time =     540.97 ms /   136 tokens (    3.98 ms per token,   251.40 tokens per second)
# llama_print_timings:        eval time =     655.33 ms /    11 runs   (   59.58 ms per token,    16.79 tokens per second)
# llama_print_timings:       total time =    1236.94 ms /   147 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      51.14 ms /    88 runs   (    0.58 ms per token,  1720.63 tokens per second)
# llama_print_timings: prompt eval time =     549.28 ms /   137 tokens (    4.01 ms per token,   249.42 tokens per second)
# llama_print_timings:        eval time =    5050.85 ms /    87 runs   (   58.06 ms per token,    17.22 tokens per second)
# llama_print_timings:       total time =    5904.69 ms /   224 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      67.08 ms /   104 runs   (    0.65 ms per token,  1550.39 tokens per second)
# llama_print_timings: prompt eval time =     800.08 ms /   293 tokens (    2.73 ms per token,   366.21 tokens per second)
# llama_print_timings:        eval time =    6162.10 ms /   103 runs   (   59.83 ms per token,    16.72 tokens per second)
# llama_print_timings:       total time =    7435.08 ms /   396 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     112.18 ms /   185 runs   (    0.61 ms per token,  1649.08 tokens per second)
# llama_print_timings: prompt eval time =     927.64 ms /   406 tokens (    2.28 ms per token,   437.67 tokens per second)
# llama_print_timings:        eval time =   11276.02 ms /   184 runs   (   61.28 ms per token,    16.32 tokens per second)
# llama_print_timings:       total time =   12959.61 ms /   590 tokens

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_4.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response
# 0   {\n"Priority": "High"\n}\n\nThe support ticke...
# 1                           {\n"Priority": "High"\n}
# 2                           {\n"Priority": "High"\n}
# 3   {\n"Priority": "Medium"\n}\n\nThe support tic...
# 4   {\n"Priority": "Medium"\n}\n\nBased on the in...

# %%
## Applying the extract_json_data function on the llama_response column to create a new column called llama_response_parsed
data_4['llama_response_parsed'] = data_4['llama_response'].apply(extract_json_data)
data_4['llama_response_parsed'].head()
# Out:
# 0      {'Priority': 'High'}
# 1      {'Priority': 'High'}
# 2      {'Priority': 'High'}
# 3    {'Priority': 'Medium'}
# 4    {'Priority': 'Medium'}
# Name: llama_response_parsed, dtype: object

# %%
## Applying the json_normalize on llama_response_parsed variable
llama_response_parsed_df_4 = pd.json_normalize(data_4['llama_response_parsed'])
llama_response_parsed_df_4.head()
# Out:
#   Priority
# 0     High
# 1     High
# 2     High
# 3   Medium
# 4   Medium

# %%
## Concatenating data_4 and llama_response_parsed_df_4
data_with_parsed_model_output_4 = pd.concat([data_4, llama_response_parsed_df_4], axis=1)
data_with_parsed_model_output_4.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response   llama_response_parsed  \
# 0   {\n"Priority": "High"\n}\n\nThe support ticke...    {'Priority': 'High'}
# 1                           {\n"Priority": "High"\n}    {'Priority': 'High'}
# 2                           {\n"Priority": "High"\n}    {'Priority': 'High'}
# 3   {\n"Priority": "Medium"\n}\n\nThe support tic...  {'Priority': 'Medium'}
# 4   {\n"Priority": "Medium"\n}\n\nBased on the in...  {'Priority': 'Medium'}
#
#   Priority
# 0     High
# 1     High
# 2     High
# 3   Medium
# 4   Medium

# %%
## Droping llama_response and llama_response_parsed variables
final_data_4 = data_with_parsed_model_output_4.drop(['llama_response','llama_response_parsed'], axis=1)
final_data_4.head(21)
# Out:
#    support_tick_id                                support_ticket_text Priority
# 0       ST2023-006  My internet connection has significantly slowe...     High
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...     High
# 2       ST2023-008  I've accidentally deleted essential work docum...     High
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...   Medium
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...   Medium
# 5       ST2023-011  I'm locked out of my online banking account an...     High
# 6       ST2023-012  My computer's performance is sluggish, severel...     High
# 7       ST2023-013  I'm experiencing a recurring blue screen error...     High
# 8       ST2023-014  My external hard drive isn't being recognized ...     High
# 9       ST2023-015  The graphics card in my gaming laptop seems to...     High
# 10      ST2023-016  I accidentally formatted my USB drive with cri...     High
# 11      ST2023-017  My computer's screen has gone black, and I can...     High
# 12      ST2023-018  I accidentally spilled water on my laptop, and...     High
# 13      ST2023-019  My USB flash drive is physically damaged, and ...     High
# 14      ST2023-020  The touchpad on my laptop has stopped working,...   Medium
# 15      ST2023-021  My internet connection is frequently dropping,...     High
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...   Medium
# 17      ST2023-023  I accidentally formatted my USB drive with cru...     High
# 18      ST2023-024  My external hard drive isn't being recognized,...     High
# 19      ST2023-025  I am experiencing a critical problem with my i...     High
# 20      ST2023-026  I hope this message finds you well. I am writi...     High

# %% [markdown]
# # Observation
#
# The model has identified the priority for each support ticket, extracted it from the JSON response, and added it to the dataset.
#
# Most tickets (17 out of 21) are marked as 'High' priority, suggesting the AI might be overly sensitive or that users report critical issues. Only 4 tickets are marked as 'Medium' priority, indicating the need to refine priority assignment criteria.

# %% [markdown]
# ## **Task 5 - Ticket Categorization, Creating Tags, Assigning Priority, Assigning ETA, and Returning Structured Output**

# %%
# Creating a copy of the data
data_5 = data.copy()

# %%
# Writing a prompt to get the desired output
instruction_5 = """
    Analyze the support ticket text provided and determine the ETA of the issue. Output the result in JSON format where the 'ETA' field is an estimated time of arrival for a response or solution and should be one of '24 hours', 'Immediate' or '2-3 business days'.

    The output should be in the form of a JSON with
    "ETA": "<ETA>"

    Replace the placeholders (<...>) with the appropriate information extracted from the support ticket text.
"""

# %%
# Creating a new column llama_response' by applying the generate_llama_response function to each ticket in the 'support_ticket_text' column of the DataFrame 'data_5'
data_5['llama_response'] = data_5['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_5,x))
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      69.20 ms /   108 runs   (    0.64 ms per token,  1560.58 tokens per second)
# llama_print_timings: prompt eval time =     564.04 ms /   186 tokens (    3.03 ms per token,   329.76 tokens per second)
# llama_print_timings:        eval time =    6408.12 ms /   107 runs   (   59.89 ms per token,    16.70 tokens per second)
# llama_print_timings:       total time =    7425.77 ms /   293 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      40.46 ms /    67 runs   (    0.60 ms per token,  1655.87 tokens per second)
# llama_print_timings: prompt eval time =     587.38 ms /   185 tokens (    3.18 ms per token,   314.96 tokens per second)
# llama_print_timings:        eval time =    3943.83 ms /    66 runs   (   59.75 ms per token,    16.74 tokens per second)
# llama_print_timings:       total time =    4778.86 ms /   251 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      46.15 ms /    78 runs   (    0.59 ms per token,  1690.07 tokens per second)
# llama_print_timings: prompt eval time =     588.27 ms /   181 tokens (    3.25 ms per token,   307.68 tokens per second)
# llama_print_timings:        eval time =    4533.23 ms /    77 runs   (   58.87 ms per token,    16.99 tokens per second)
# llama_print_timings:       total time =    5393.24 ms /   258 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      75.95 ms /   118 runs   (    0.64 ms per token,  1553.67 tokens per second)
# llama_print_timings: prompt eval time =     597.80 ms /   189 tokens (    3.16 ms per token,   316.16 tokens per second)
# llama_print_timings:        eval time =    6947.41 ms /   117 runs   (   59.38 ms per token,    16.84 tokens per second)
# llama_print_timings:       total time =    8057.85 ms /   306 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      54.37 ms /    90 runs   (    0.60 ms per token,  1655.20 tokens per second)
# llama_print_timings: prompt eval time =     579.78 ms /   164 tokens (    3.54 ms per token,   282.87 tokens per second)
# llama_print_timings:        eval time =    5259.66 ms /    89 runs   (   59.10 ms per token,    16.92 tokens per second)
# llama_print_timings:       total time =    6179.88 ms /   253 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      71.67 ms /   119 runs   (    0.60 ms per token,  1660.46 tokens per second)
# llama_print_timings: prompt eval time =     565.02 ms /   164 tokens (    3.45 ms per token,   290.26 tokens per second)
# llama_print_timings:        eval time =    7048.94 ms /   118 runs   (   59.74 ms per token,    16.74 tokens per second)
# llama_print_timings:       total time =    8082.17 ms /   282 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      50.05 ms /    77 runs   (    0.65 ms per token,  1538.43 tokens per second)
# llama_print_timings: prompt eval time =     578.85 ms /   167 tokens (    3.47 ms per token,   288.51 tokens per second)
# llama_print_timings:        eval time =    4551.62 ms /    76 runs   (   59.89 ms per token,    16.70 tokens per second)
# llama_print_timings:       total time =    5461.92 ms /   243 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      99.52 ms /   164 runs   (    0.61 ms per token,  1647.86 tokens per second)
# llama_print_timings: prompt eval time =     576.39 ms /   168 tokens (    3.43 ms per token,   291.47 tokens per second)
# llama_print_timings:        eval time =    9852.39 ms /   163 runs   (   60.44 ms per token,    16.54 tokens per second)
# llama_print_timings:       total time =   11057.01 ms /   331 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      68.28 ms /   106 runs   (    0.64 ms per token,  1552.54 tokens per second)
# llama_print_timings: prompt eval time =     575.37 ms /   162 tokens (    3.55 ms per token,   281.56 tokens per second)
# llama_print_timings:        eval time =    6249.04 ms /   105 runs   (   59.51 ms per token,    16.80 tokens per second)
# llama_print_timings:       total time =    7293.29 ms /   267 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =     102.83 ms /   165 runs   (    0.62 ms per token,  1604.54 tokens per second)
# llama_print_timings: prompt eval time =     582.33 ms /   171 tokens (    3.41 ms per token,   293.65 tokens per second)
# llama_print_timings:        eval time =    9799.68 ms /   164 runs   (   59.75 ms per token,    16.74 tokens per second)
# llama_print_timings:       total time =   11078.44 ms /   335 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      54.89 ms /    93 runs   (    0.59 ms per token,  1694.24 tokens per second)
# llama_print_timings: prompt eval time =     576.91 ms /   164 tokens (    3.52 ms per token,   284.27 tokens per second)
# llama_print_timings:        eval time =    5524.60 ms /    92 runs   (   60.05 ms per token,    16.65 tokens per second)
# llama_print_timings:       total time =    6426.15 ms /   256 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      56.67 ms /    88 runs   (    0.64 ms per token,  1552.90 tokens per second)
# llama_print_timings: prompt eval time =     577.09 ms /   168 tokens (    3.44 ms per token,   291.12 tokens per second)
# llama_print_timings:        eval time =    5165.41 ms /    87 runs   (   59.37 ms per token,    16.84 tokens per second)
# llama_print_timings:       total time =    6142.54 ms /   255 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      49.40 ms /    85 runs   (    0.58 ms per token,  1720.61 tokens per second)
# llama_print_timings: prompt eval time =     574.24 ms /   168 tokens (    3.42 ms per token,   292.56 tokens per second)
# llama_print_timings:        eval time =    5012.53 ms /    84 runs   (   59.67 ms per token,    16.76 tokens per second)
# llama_print_timings:       total time =    5896.45 ms /   252 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      51.52 ms /    75 runs   (    0.69 ms per token,  1455.89 tokens per second)
# llama_print_timings: prompt eval time =     564.32 ms /   160 tokens (    3.53 ms per token,   283.53 tokens per second)
# llama_print_timings:        eval time =    4345.72 ms /    74 runs   (   58.73 ms per token,    17.03 tokens per second)
# llama_print_timings:       total time =    5277.80 ms /   234 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      51.66 ms /    87 runs   (    0.59 ms per token,  1684.22 tokens per second)
# llama_print_timings: prompt eval time =     576.64 ms /   165 tokens (    3.49 ms per token,   286.14 tokens per second)
# llama_print_timings:        eval time =    5141.50 ms /    86 runs   (   59.78 ms per token,    16.73 tokens per second)
# llama_print_timings:       total time =    6022.28 ms /   251 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      73.41 ms /   114 runs   (    0.64 ms per token,  1552.88 tokens per second)
# llama_print_timings: prompt eval time =     582.88 ms /   156 tokens (    3.74 ms per token,   267.64 tokens per second)
# llama_print_timings:        eval time =    6720.00 ms /   113 runs   (   59.47 ms per token,    16.82 tokens per second)
# llama_print_timings:       total time =    7811.77 ms /   269 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      47.07 ms /    82 runs   (    0.57 ms per token,  1742.01 tokens per second)
# llama_print_timings: prompt eval time =     574.73 ms /   161 tokens (    3.57 ms per token,   280.13 tokens per second)
# llama_print_timings:        eval time =    4859.52 ms /    81 runs   (   59.99 ms per token,    16.67 tokens per second)
# llama_print_timings:       total time =    5721.69 ms /   242 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      54.09 ms /    80 runs   (    0.68 ms per token,  1478.99 tokens per second)
# llama_print_timings: prompt eval time =     568.77 ms /   156 tokens (    3.65 ms per token,   274.28 tokens per second)
# llama_print_timings:        eval time =    4598.44 ms /    79 runs   (   58.21 ms per token,    17.18 tokens per second)
# llama_print_timings:       total time =    5545.21 ms /   235 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      77.27 ms /   132 runs   (    0.59 ms per token,  1708.21 tokens per second)
# llama_print_timings: prompt eval time =     563.54 ms /   157 tokens (    3.59 ms per token,   278.60 tokens per second)
# llama_print_timings:        eval time =    7890.15 ms /   131 runs   (   60.23 ms per token,    16.60 tokens per second)
# llama_print_timings:       total time =    8926.13 ms /   288 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      89.05 ms /   142 runs   (    0.63 ms per token,  1594.66 tokens per second)
# llama_print_timings: prompt eval time =     810.66 ms /   313 tokens (    2.59 ms per token,   386.10 tokens per second)
# llama_print_timings:        eval time =    8576.77 ms /   141 runs   (   60.83 ms per token,    16.44 tokens per second)
# llama_print_timings:       total time =    9999.64 ms /   454 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      60.46 ms /    94 runs   (    0.64 ms per token,  1554.80 tokens per second)
# llama_print_timings: prompt eval time =     954.93 ms /   426 tokens (    2.24 ms per token,   446.11 tokens per second)
# llama_print_timings:        eval time =    5670.03 ms /    93 runs   (   60.97 ms per token,    16.40 tokens per second)
# llama_print_timings:       total time =    7056.69 ms /   519 tokens

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_5.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response
# 0   {\n"ETA": "24 hours"\n}\n\nBased on the infor...
# 1   {\n"ETA": "Immediate"\n}\n\nBased on the info...
# 2   {\n"ETA": "Immediate"\n}\n\nBased on the info...
# 3   {\n"ETA": "2-3 business days"\n}\n\nBased on ...
# 4  \n    {\n      "ETA": "24 hours"\n    }\n    \...

# %%
## Applying the extract_json_data function on the llama_response column to create a new column called llama_response_parsed
data_5['llama_response_parsed'] = data_5['llama_response'].apply(extract_json_data)
data_5['llama_response_parsed'].head()
# Out:
# 0             {'ETA': '24 hours'}
# 1            {'ETA': 'Immediate'}
# 2            {'ETA': 'Immediate'}
# 3    {'ETA': '2-3 business days'}
# 4             {'ETA': '24 hours'}
# Name: llama_response_parsed, dtype: object

# %%
## Applying the json_normalize on llama_response_parsed variable
llama_response_parsed_df_5 = pd.json_normalize(data_5['llama_response_parsed'])
llama_response_parsed_df_5.head()
# Out:
#                  ETA
# 0           24 hours
# 1          Immediate
# 2          Immediate
# 3  2-3 business days
# 4           24 hours

# %%
## Concatenating data_5 and llama_response_parsed_df_5
data_with_parsed_model_output_5 = pd.concat([data_5, llama_response_parsed_df_5], axis=1)
data_with_parsed_model_output_5.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response  \
# 0   {\n"ETA": "24 hours"\n}\n\nBased on the infor...
# 1   {\n"ETA": "Immediate"\n}\n\nBased on the info...
# 2   {\n"ETA": "Immediate"\n}\n\nBased on the info...
# 3   {\n"ETA": "2-3 business days"\n}\n\nBased on ...
# 4  \n    {\n      "ETA": "24 hours"\n    }\n    \...
#
#           llama_response_parsed                ETA
# 0           {'ETA': '24 hours'}           24 hours
# 1          {'ETA': 'Immediate'}          Immediate
# 2          {'ETA': 'Immediate'}          Immediate
# 3  {'ETA': '2-3 business days'}  2-3 business days
# 4           {'ETA': '24 hours'}           24 hours

# %%
## Dropping llama_response and llama_response_parsed variables
final_data_5 = data_with_parsed_model_output_5.drop(['llama_response','llama_response_parsed'], axis=1)
final_data_5.head(21)
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#                   ETA
# 0            24 hours
# 1           Immediate
# 2           Immediate
# 3   2-3 business days
# 4            24 hours
# 5           Immediate
# 6   2-3 business days
# 7   2-3 business days
# 8   2-3 business days
# 9   2-3 business days
# 10           24 hours
# 11          Immediate
# 12           24 hours
# 13           24 hours
# 14           24 hours
# 15           24 hours
# 16           24 hours
# 17           24 hours
# 18  2-3 business days
# 19          Immediate
# 20  2-3 business days

# %% [markdown]
# # Observation
#
# * The model has identified the ETA for each support ticket, extracted this information from the JSON response, and added it to the dataset.
#
# * ETAs are well-distributed: '24 hours' is the most common (9 tickets), followed by '2-3 business days' (7 tickets), and 'Immediate' (5 tickets).
#  * This indicates a responsive IT support structure focused on quick issue resolution.

# %% [markdown]
# ## **Task 6 - Ticket Categorization, Creating Tags, Assigning Priority, Assigning ETA, Creating a Draft Response, and Returning Structured Output**

# %%
# Creating a copy of the data
data_6 = data.copy()

# %%
instruction_6 = """
    Your task is to read the support ticket text and generate a brief customer service response addressing the issue. The response must be written in valid JSON format. It is crucial that your output strictly adheres to the JSON structure, with no exceptions. Here is the template you must use:

    {"Response": "Type your customer service response here."}

    For example, if the support ticket says, "My laptop screen is flickering," your output should look like:

    {"Response": "We're sorry to hear that your laptop screen is flickering. It may be an issue with the display driver or the hardware. We recommend restarting your laptop and updating the display drivers. If the problem continues, please contact our support team for a detailed troubleshooting guide."}

    Now, apply this template to generate a response for the new support ticket text:

    {"Response": "<Your Customer Service Response Here>"}

    Remember, only the placeholder text in quotes should be replaced, and the response must be enclosed in quotation marks to maintain valid JSON format.
"""

# %%
# Creating a new column llama_response' by applying the generate_llama_response function to each ticket in the 'support_ticket_text' column of the DataFrame 'data_6'
data_6['llama_response'] = data_6['support_ticket_text'].apply(lambda x: generate_llama_response(instruction_6,x))
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      48.88 ms /    82 runs   (    0.60 ms per token,  1677.54 tokens per second)
# llama_print_timings: prompt eval time =     811.96 ms /   308 tokens (    2.64 ms per token,   379.33 tokens per second)
# llama_print_timings:        eval time =    5014.99 ms /    81 runs   (   61.91 ms per token,    16.15 tokens per second)
# llama_print_timings:       total time =    6123.25 ms /   389 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      55.46 ms /    84 runs   (    0.66 ms per token,  1514.52 tokens per second)
# llama_print_timings: prompt eval time =     800.33 ms /   307 tokens (    2.61 ms per token,   383.59 tokens per second)
# llama_print_timings:        eval time =    5019.11 ms /    83 runs   (   60.47 ms per token,    16.54 tokens per second)
# llama_print_timings:       total time =    6215.68 ms /   390 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      50.21 ms /    84 runs   (    0.60 ms per token,  1672.94 tokens per second)
# llama_print_timings: prompt eval time =     808.59 ms /   303 tokens (    2.67 ms per token,   374.73 tokens per second)
# llama_print_timings:        eval time =    5053.76 ms /    83 runs   (   60.89 ms per token,    16.42 tokens per second)
# llama_print_timings:       total time =    6180.32 ms /   386 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      70.03 ms /   114 runs   (    0.61 ms per token,  1627.85 tokens per second)
# llama_print_timings: prompt eval time =     804.90 ms /   311 tokens (    2.59 ms per token,   386.38 tokens per second)
# llama_print_timings:        eval time =    6850.26 ms /   113 runs   (   60.62 ms per token,    16.50 tokens per second)
# llama_print_timings:       total time =    8158.37 ms /   424 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      82.76 ms /   137 runs   (    0.60 ms per token,  1655.33 tokens per second)
# llama_print_timings: prompt eval time =     804.93 ms /   286 tokens (    2.81 ms per token,   355.31 tokens per second)
# llama_print_timings:        eval time =    8307.08 ms /   136 runs   (   61.08 ms per token,    16.37 tokens per second)
# llama_print_timings:       total time =    9643.74 ms /   422 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      58.30 ms /    97 runs   (    0.60 ms per token,  1663.95 tokens per second)
# llama_print_timings: prompt eval time =     815.26 ms /   286 tokens (    2.85 ms per token,   350.81 tokens per second)
# llama_print_timings:        eval time =    5873.01 ms /    96 runs   (   61.18 ms per token,    16.35 tokens per second)
# llama_print_timings:       total time =    7057.48 ms /   382 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      80.81 ms /   125 runs   (    0.65 ms per token,  1546.84 tokens per second)
# llama_print_timings: prompt eval time =     803.34 ms /   289 tokens (    2.78 ms per token,   359.75 tokens per second)
# llama_print_timings:        eval time =    7473.27 ms /   124 runs   (   60.27 ms per token,    16.59 tokens per second)
# llama_print_timings:       total time =    8831.42 ms /   413 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      85.71 ms /   139 runs   (    0.62 ms per token,  1621.82 tokens per second)
# llama_print_timings: prompt eval time =     805.40 ms /   290 tokens (    2.78 ms per token,   360.07 tokens per second)
# llama_print_timings:        eval time =    8439.84 ms /   138 runs   (   61.16 ms per token,    16.35 tokens per second)
# llama_print_timings:       total time =    9806.97 ms /   428 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      56.22 ms /    92 runs   (    0.61 ms per token,  1636.40 tokens per second)
# llama_print_timings: prompt eval time =     790.03 ms /   284 tokens (    2.78 ms per token,   359.48 tokens per second)
# llama_print_timings:        eval time =    5538.40 ms /    91 runs   (   60.86 ms per token,    16.43 tokens per second)
# llama_print_timings:       total time =    6681.63 ms /   375 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      65.17 ms /   100 runs   (    0.65 ms per token,  1534.50 tokens per second)
# llama_print_timings: prompt eval time =     797.48 ms /   293 tokens (    2.72 ms per token,   367.41 tokens per second)
# llama_print_timings:        eval time =    5966.32 ms /    99 runs   (   60.27 ms per token,    16.59 tokens per second)
# llama_print_timings:       total time =    7235.89 ms /   392 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      80.67 ms /   138 runs   (    0.58 ms per token,  1710.67 tokens per second)
# llama_print_timings: prompt eval time =     797.80 ms /   286 tokens (    2.79 ms per token,   358.49 tokens per second)
# llama_print_timings:        eval time =    8357.48 ms /   137 runs   (   61.00 ms per token,    16.39 tokens per second)
# llama_print_timings:       total time =    9649.02 ms /   423 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      65.57 ms /   103 runs   (    0.64 ms per token,  1570.91 tokens per second)
# llama_print_timings: prompt eval time =     810.49 ms /   290 tokens (    2.79 ms per token,   357.81 tokens per second)
# llama_print_timings:        eval time =    6188.68 ms /   102 runs   (   60.67 ms per token,    16.48 tokens per second)
# llama_print_timings:       total time =    7457.04 ms /   392 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      34.87 ms /    61 runs   (    0.57 ms per token,  1749.15 tokens per second)
# llama_print_timings: prompt eval time =     806.37 ms /   290 tokens (    2.78 ms per token,   359.64 tokens per second)
# llama_print_timings:        eval time =    3648.49 ms /    60 runs   (   60.81 ms per token,    16.45 tokens per second)
# llama_print_timings:       total time =    4665.33 ms /   350 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      51.12 ms /    77 runs   (    0.66 ms per token,  1506.38 tokens per second)
# llama_print_timings: prompt eval time =     801.66 ms /   282 tokens (    2.84 ms per token,   351.77 tokens per second)
# llama_print_timings:        eval time =    4547.33 ms /    76 runs   (   59.83 ms per token,    16.71 tokens per second)
# llama_print_timings:       total time =    5722.77 ms /   358 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      40.77 ms /    69 runs   (    0.59 ms per token,  1692.42 tokens per second)
# llama_print_timings: prompt eval time =     805.71 ms /   287 tokens (    2.81 ms per token,   356.21 tokens per second)
# llama_print_timings:        eval time =    4120.74 ms /    68 runs   (   60.60 ms per token,    16.50 tokens per second)
# llama_print_timings:       total time =    5177.97 ms /   355 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      42.42 ms /    66 runs   (    0.64 ms per token,  1555.87 tokens per second)
# llama_print_timings: prompt eval time =     811.21 ms /   278 tokens (    2.92 ms per token,   342.70 tokens per second)
# llama_print_timings:        eval time =    3906.63 ms /    65 runs   (   60.10 ms per token,    16.64 tokens per second)
# llama_print_timings:       total time =    5011.45 ms /   343 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      87.57 ms /   153 runs   (    0.57 ms per token,  1747.23 tokens per second)
# llama_print_timings: prompt eval time =     800.16 ms /   283 tokens (    2.83 ms per token,   353.68 tokens per second)
# llama_print_timings:        eval time =    9298.41 ms /   152 runs   (   61.17 ms per token,    16.35 tokens per second)
# llama_print_timings:       total time =   10665.18 ms /   435 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      63.23 ms /    99 runs   (    0.64 ms per token,  1565.69 tokens per second)
# llama_print_timings: prompt eval time =     800.46 ms /   278 tokens (    2.88 ms per token,   347.30 tokens per second)
# llama_print_timings:        eval time =    5912.90 ms /    98 runs   (   60.34 ms per token,    16.57 tokens per second)
# llama_print_timings:       total time =    7155.92 ms /   376 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      55.51 ms /    91 runs   (    0.61 ms per token,  1639.34 tokens per second)
# llama_print_timings: prompt eval time =     801.66 ms /   279 tokens (    2.87 ms per token,   348.03 tokens per second)
# llama_print_timings:        eval time =    5475.56 ms /    90 runs   (   60.84 ms per token,    16.44 tokens per second)
# llama_print_timings:       total time =    6642.35 ms /   369 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      74.73 ms /   122 runs   (    0.61 ms per token,  1632.43 tokens per second)
# llama_print_timings: prompt eval time =     968.24 ms /   435 tokens (    2.23 ms per token,   449.27 tokens per second)
# llama_print_timings:        eval time =    7449.11 ms /   121 runs   (   61.56 ms per token,    16.24 tokens per second)
# llama_print_timings:       total time =    8905.26 ms /   556 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     766.75 ms
# llama_print_timings:      sample time =      72.25 ms /   115 runs   (    0.63 ms per token,  1591.63 tokens per second)
# llama_print_timings: prompt eval time =    1446.00 ms /   548 tokens (    2.64 ms per token,   378.98 tokens per second)
# llama_print_timings:        eval time =    7035.71 ms /   114 runs   (   61.72 ms per token,    16.20 tokens per second)
# llama_print_timings:       total time =    9006.38 ms /   662 tokens

# %%
# Checking the first five rows of the data to confirm whether the new column has been added
data_6.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response
# 0   Sure! Here's a brief customer service respons...
# 1   {"Response": "We apologize for the inconvenie...
# 2   Sure! Here's your customer service response i...
# 3   Sure! Here is a brief customer service respon...
# 4   Sure! Here's my response: \n\n{"Response": "T...

# %%
## Appling the extract_json_data function on the llama_response column to create a new column called llama_response_parsed
data_6['llama_response_parsed'] = data_6['llama_response'].apply(extract_json_data)
data_6['llama_response_parsed'].head()
# Out:
# 0    {'Response': 'We apologize for any inconvenien...
# 1    {'Response': 'We apologize for the inconvenien...
# 2    {'Response': 'We apologize for any inconvenien...
# 3    {'Response': 'Thank you for reaching out about...
# 4    {'Response': 'Thank you for reaching out! We a...
# Name: llama_response_parsed, dtype: object

# %%
## Applying the normalize on llama_response_parsed variable
llama_response_parsed_df_6= pd.json_normalize(data_6['llama_response_parsed'])
llama_response_parsed_df_6.head()
# Out:
#                                             Response
# 0  We apologize for any inconvenience caused by y...
# 1  We apologize for the inconvenience you are exp...
# 2  We apologize for any inconvenience caused by t...
# 3  Thank you for reaching out about your persiste...
# 4  Thank you for reaching out! We apologize for a...

# %%
## Concatenating data_6 and llama_response_parsed_df_6
data_with_parsed_model_output_6 = pd.concat([data_6, llama_response_parsed_df_6], axis=1)
data_with_parsed_model_output_6.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2023-006  My internet connection has significantly slowe...
# 1      ST2023-007  Urgent help required! My laptop refuses to sta...
# 2      ST2023-008  I've accidentally deleted essential work docum...
# 3      ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4      ST2023-010  My smartphone battery is draining rapidly, eve...
#
#                                       llama_response  \
# 0   Sure! Here's a brief customer service respons...
# 1   {"Response": "We apologize for the inconvenie...
# 2   Sure! Here's your customer service response i...
# 3   Sure! Here is a brief customer service respon...
# 4   Sure! Here's my response: \n\n{"Response": "T...
#
#                                llama_response_parsed  \
# 0  {'Response': 'We apologize for any inconvenien...
# 1  {'Response': 'We apologize for the inconvenien...
# 2  {'Response': 'We apologize for any inconvenien...
# 3  {'Response': 'Thank you for reaching out about...
# 4  {'Response': 'Thank you for reaching out! We a...
#
#                                             Response
# 0  We apologize for any inconvenience caused by y...
# 1  We apologize for the inconvenience you are exp...
# 2  We apologize for any inconvenience caused by t...
# 3  Thank you for reaching out about your persiste...
# 4  Thank you for reaching out! We apologize for a...

# %%
## Droping llama_response and llama_response_parsed variables
final_data_6 = data_with_parsed_model_output_6.drop(['llama_response','llama_response_parsed'], axis=1)
final_data_6.head(21)
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#                                              Response
# 0   We apologize for any inconvenience caused by y...
# 1   We apologize for the inconvenience you are exp...
# 2   We apologize for any inconvenience caused by t...
# 3   Thank you for reaching out about your persiste...
# 4   Thank you for reaching out! We apologize for a...
# 5   We apologize for any inconvenience you may hav...
# 6   We apologize for any inconvenience caused by y...
# 7   We apologize for the inconvenience caused by t...
# 8   We apologize for any inconvenience caused by y...
# 9   We're sorry to hear that your graphics card ap...
# 10  We apologize for any inconvenience caused by f...
# 11  We apologize for any inconvenience caused by y...
# 12  We regret that your laptop may have been damag...
# 13  We're sorry to hear that your USB flash drive ...
# 14  We're sorry to hear that your touchpad isn't f...
# 15  We apologize for any inconvenience caused by y...
# 16  Thank you for reaching out to us about your Wi...
# 17  We're sorry to hear that you accidentally form...
# 18  We apologize for any inconvenience caused by y...
# 19  We apologize for the inconvenience you are exp...
# 20  Thank you for bringing this issue to our atten...

# %% [markdown]
# # Observation
#
# The model has successfully generated a concise customer service response for each support ticket.

# %% [markdown]
# ## **Model Output Analysis**

# %%
# Creating a copy of the dataframe
columns_to_add = [df.iloc[:, -1] for df in [final_data_3, final_data_4, final_data_5, final_data_6]]
final_data = pd.concat([final_data_2] + columns_to_add, axis=1)

# %%
# Printing the final dataframe
final_data
# Out:
#    support_tick_id                                support_ticket_text  \
# 0       ST2023-006  My internet connection has significantly slowe...
# 1       ST2023-007  Urgent help required! My laptop refuses to sta...
# 2       ST2023-008  I've accidentally deleted essential work docum...
# 3       ST2023-009  Despite being in close proximity to my Wi-Fi r...
# 4       ST2023-010  My smartphone battery is draining rapidly, eve...
# 5       ST2023-011  I'm locked out of my online banking account an...
# 6       ST2023-012  My computer's performance is sluggish, severel...
# 7       ST2023-013  I'm experiencing a recurring blue screen error...
# 8       ST2023-014  My external hard drive isn't being recognized ...
# 9       ST2023-015  The graphics card in my gaming laptop seems to...
# 10      ST2023-016  I accidentally formatted my USB drive with cri...
# 11      ST2023-017  My computer's screen has gone black, and I can...
# 12      ST2023-018  I accidentally spilled water on my laptop, and...
# 13      ST2023-019  My USB flash drive is physically damaged, and ...
# 14      ST2023-020  The touchpad on my laptop has stopped working,...
# 15      ST2023-021  My internet connection is frequently dropping,...
# 16      ST2023-022  Wi-Fi is inconsistent despite proximity to the...
# 17      ST2023-023  I accidentally formatted my USB drive with cru...
# 18      ST2023-024  My external hard drive isn't being recognized,...
# 19      ST2023-025  I am experiencing a critical problem with my i...
# 20      ST2023-026  I hope this message finds you well. I am writi...
#
#             Category                                               Tags  \
# 0   Technical Issues  [Internet Connection, Speed, Disconnections, W...
# 1    Hardware Issues  [urgent, laptop, start, hardware, issue, prese...
# 2      Data Recovery  [Data Loss, Essential Documents, Accidental De...
# 3   Technical Issues  [Wi-Fi, signal strength, weak, persistent, hom...
# 4   Technical Issues  [battery, draining, rapidly, minimal, use, issue]
# 5   Technical Issues  [urgent, transaction, password, reset, online,...
# 6   Technical Issues  [Computer Performance, Sluggish, Productivity,...
# 7    Hardware Issues  [Blue Screen Error, Frequent Crashes, Hardware...
# 8      Data Recovery  [Data Recovery, External Hard Drive, Not Recog...
# 9    Hardware Issues  [hardware issue, graphics card, poor gaming pe...
# 10     Data Recovery  [data loss, USB drive, critical files, recover...
# 11   Hardware Issues  [computer, screen, black, fix, urgent, assista...
# 12     Data Recovery       [Water Damage, Laptop, Data Recovery, Spill]
# 13     Data Recovery  [USB Flash Drive, Physical Damage, File Recove...
# 14   Hardware Issues  [hardware, touchpad, laptop, troubleshooting, ...
# 15  Technical Issues  [internet connection, dropping, frequently, ur...
# 16  Technical Issues     [Wi-Fi, inconsistent, proximity, router, work]
# 17     Data Recovery  [Data Recovery, USB Drive, Formatted, Crucial ...
# 18     Data Recovery  [Hard Drive, Recognition, Data Recovery, Exter...
# 19  Technical Issues  [Internet Connection, Speed, Disconnections, P...
# 20  Technical Issues  [software compatibility, erratic behavior, dat...
#
#    Priority                ETA  \
# 0      High           24 hours
# 1      High          Immediate
# 2      High          Immediate
# 3    Medium  2-3 business days
# 4    Medium           24 hours
# 5      High          Immediate
# 6      High  2-3 business days
# 7      High  2-3 business days
# 8      High  2-3 business days
# 9      High  2-3 business days
# 10     High           24 hours
# 11     High          Immediate
# 12     High           24 hours
# 13     High           24 hours
# 14   Medium           24 hours
# 15     High           24 hours
# 16   Medium           24 hours
# 17     High           24 hours
# 18     High  2-3 business days
# 19     High          Immediate
# 20     High  2-3 business days
#
#                                              Response
# 0   We apologize for any inconvenience caused by y...
# 1   We apologize for the inconvenience you are exp...
# 2   We apologize for any inconvenience caused by t...
# 3   Thank you for reaching out about your persiste...
# 4   Thank you for reaching out! We apologize for a...
# 5   We apologize for any inconvenience you may hav...
# 6   We apologize for any inconvenience caused by y...
# 7   We apologize for the inconvenience caused by t...
# 8   We apologize for any inconvenience caused by y...
# 9   We're sorry to hear that your graphics card ap...
# 10  We apologize for any inconvenience caused by f...
# 11  We apologize for any inconvenience caused by y...
# 12  We regret that your laptop may have been damag...
# 13  We're sorry to hear that your USB flash drive ...
# 14  We're sorry to hear that your touchpad isn't f...
# 15  We apologize for any inconvenience caused by y...
# 16  Thank you for reaching out to us about your Wi...
# 17  We're sorry to hear that you accidentally form...
# 18  We apologize for any inconvenience caused by y...
# 19  We apologize for the inconvenience you are exp...
# 20  Thank you for bringing this issue to our atten...

# %%
# Checking the distribution of categories
final_data['Category'].value_counts()
# Out:
# Technical Issues    9
# Data Recovery       7
# Hardware Issues     5
# Name: Category, dtype: int64

# %%
# Checking the distribution of priority
final_data['Priority'].value_counts()
# Out:
# High      17
# Medium     4
# Name: Priority, dtype: int64

# %%
# Checking the distribution of ETA
final_data['ETA'].value_counts()
# Out:
# 24 hours             9
# 2-3 business days    7
# Immediate            5
# Name: ETA, dtype: int64

# %%
# Checking the distribution of priority by categories
final_data.groupby(['Category', 'Priority']).support_tick_id.count()
# Out:
# Category          Priority
# Data Recovery     High        7
# Hardware Issues   High        4
#                   Medium      1
# Technical Issues  High        6
#                   Medium      3
# Name: support_tick_id, dtype: int64

# %%
# Checking the distribution of ETA by categories
final_data.groupby(['Category', 'ETA']).support_tick_id.count()
# Out:
# Category          ETA
# Data Recovery     2-3 business days    2
#                   24 hours             4
#                   Immediate            1
# Hardware Issues   2-3 business days    2
#                   24 hours             1
#                   Immediate            2
# Technical Issues  2-3 business days    3
#                   24 hours             4
#                   Immediate            2
# Name: support_tick_id, dtype: int64

# %% [markdown]
# **Observations**
#
# Support Ticket Analysis
#
# **Category Distribution:**
#
# Technical Issues: Most common (9 tickets).
#
# * Data Recovery: 7 tickets.
#
# * Hardware Issues: Least frequent (5 tickets).
#
# * Insight: Users face more technical issues than hardware problems or data loss.
#
# **Priority Levels:**
#
# * High Priority: 17 tickets.
# * Medium Priority: 4 tickets.
# * Insight: High number of high-priority tickets may indicate AI sensitivity or critical nature of issues. Priority criteria may need refinement.
#
# **Estimated Resolution Times (ETA):**
#
# * 24 Hours: Most common (9 tickets).
# * 2-3 Business Days: 7 tickets.
# * Immediate: 5 tickets.
# * Insight: Responsive IT support aims for quick resolution.
#
# **Category vs. Priority:**
#
# * Data Recovery: All high priority.
# * Hardware Issues: Mostly high priority, one medium.
# * Technical Issues: Mixed priorities, more high than medium.
#
# **Category vs. ETA:**
#
# * Data Recovery: Mostly resolved within 24 hours, some variability.
# * Hardware Issues: Spread across all ETAs, case-by-case approach.
# * Technical Issues: Mostly resolved within 24 hours or 2-3 business days, less urgency than Data Recovery.

# %% [markdown]
# **Actionable Insights and Recommendations**

# %% [markdown]
# 1- We can implement a feedback mechanism, allowing support agents to adjust or confirm AI categorization and priority settings, utilizing reinforcement learning for continuous improvement. This iterative process enables the AI to refine its accuracy over time.
#
# 2- To improve the model we can update design of prompts and adjust model parameters such as
# * temperature to regulate response randomness,
# * top_p to manage response diversity, or
# * top_k to limit the maximum number of likely next tokens in the generated response.
#
# 3- While responses are based on sentiment analysis, they may appear generic. Enhancing sentiment analysis to detect varying levels of frustration or urgency in ticket text would enable more tailored responses.
#
# 4- To address recurring issues such as blue screen errors or hardware failures, we can integrate predictive maintenance tips into responses, mitigating future tickets on the same issue.
#
# 5- Reviewing ETA for resolution times ensures alignment with issue urgency and complexity. Implementation of a dynamic ETA predictor, learning from past ticket data, would provide more accurate estimates.
#
# 6- To keep pace with evolving technology and common issues, regular model retraining intervals with new data are essential to stay updated with the latest tech support challenges and solutions.
